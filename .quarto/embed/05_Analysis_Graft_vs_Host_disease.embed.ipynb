# %% [markdown]
# # 05_Analysis_Graft_vs_Host_disease
#
# # Graft vs. host disease in relation to Survival
#
# Dataset: *Bone Marrow Transplantation: Children*
#
# *Exporatory Anlysis. Not included in the slides.*
#
# We want to look at the relationship between relapse and secondary
# transplants in patients and how it affects their odds of survival.
#
# Variables used:
#
# | Variable | Description | Value | Missing values |
# |:----------------:|:----------------:|:----------------:|------------------|
# | `aGvHDIIIIV` | Development of acute graft versus host disease stage III or IV | Yes, No | No, kind of |
# | `extcGvHD` | Development of extensive chronic graft versus host disease | Yes, No | Yes |
# | `time_to_aGvHD_III_IV` | Time to development of acute graft versus host disease stage III or IV | Integer, time in days | No |
#
# Table 1: The data used for this analysis is from `03_dat_aug` ? using
# these variables: `aGvHDIIIIV`, `extcGvHD`, `time_to_aGvHD_III_IV`.
#
# ## Data Wrangling
#
# ### Initiate Libraries
#
# We start by loading the relevant libraries.

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   4.0.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# We then load a subset of the cleaned and augmented data frame as a
# tibble.

# %%
bm_data <- read_tsv(file = "data/03_dat_aug.tsv.gz",
                            show_col_types = FALSE)

# %% [markdown]
# It contains 186 values and follows the guidelines for tidy data, with:
#
# -   Each variable having its own column.
#
# -   Each observation having its own row.
#
# -   Each value having its own cell.
#
# Some variables used in this analysis contains missing values or very
# high values, see table 1 for more details. The high values correspond
# with other data.
#
# The full tibble can be seen here.

# %%
bm_data
# Out:
# # A tibble: 186 × 35
#    Recipientgender Stemcellsource Donorage Donorage35 IIIV  Gendermatch DonorABO
#    <chr>           <chr>             <dbl>      <dbl> <chr> <chr>       <chr>
#  1 Male            Bone marrow        23.3          0 Yes   Other       B
#  2 Male            Bone marrow        26.4          0 Yes   Other       B
#  3 Female          Bone marrow        39.7          1 Yes   Other       A
#  4 Female          Pheripheral b…     33.4          0 No    Other       A
#  5 Male            Bone marrow        27.4          0 No    Other       AB
#  6 Female          Pheripheral b…     34.5          0 Yes   Other       0
#  7 Male            Bone marrow        21.4          0 Yes   Other       0
#  8 Male            Pheripheral b…     32.6          0 No    Other       AB
#  9 Male            Pheripheral b…     28.8          0 Yes   Female to … A
# 10 Female          Pheripheral b…     29.7          0 No    Other       0
# # ℹ 176 more rows
# # ℹ 28 more variables: RecipientABO <chr>, RecipientRh <chr>, ABOmatch <chr>,
# #   CMVstatus <dbl>, DonorCMV <chr>, RecipientCMV <chr>, Disease <chr>,
# #   Riskgroup <chr>, Txpostrelapse <chr>, Diseasegroup <chr>, HLAmatch <chr>,
# #   HLAmismatch <chr>, Antigen <chr>, Alel <chr>, HLAgrI <chr>,
# #   Recipientage <dbl>, Relapse <chr>, aGvHDIIIIV <chr>, extcGvHD <chr>,
# #   CD34kgx10d6 <dbl>, CD3dCD34 <dbl>, CD3dkgx10d8 <dbl>, Rbodymass <dbl>, …

# %% [markdown]
# ## Data Analysis
#
# ### Development of Acute Graft
#
# We look at the time it takes to develop acute graft vs. host disease and
# how the data is structured.
#
# We do this by creating a subset using 2 variables to look into the
# development of acute graft vs. host disease stage III & IV.

# %%
acute_graft_data <- bm_data |>
  select(aGvHDIIIIV,
         time_to_aGvHD_III_IV) 

acute_graft_data
# Out:
# # A tibble: 186 × 2
#    aGvHDIIIIV time_to_aGvHD_III_IV
#    <chr>                     <dbl>
#  1 No                      1000000
#  2 No                      1000000
#  3 Yes                          19
#  4 No                      1000000
#  5 No                      1000000
#  6 Yes                          18
#  7 Yes                          22
#  8 No                      1000000
#  9 No                      1000000
# 10 No                      1000000
# # ℹ 176 more rows

# %% [markdown]
# Further look into values.

# %%
acute_graft_data |>
  filter(aGvHDIIIIV == "Yes") |>
  summarise()
# Out:
# # A tibble: 1 × 0

# %% [markdown]
# We see that entries with no development of acute graft vs. host disease
# has been marked with high values of 10^6 days.
#
# If we filter by they patients that accuiqred acute graft vs. host
# disease we see that

# %%
acute_graft_data |>
  filter(aGvHDIIIIV == "Yes") |>
  ggplot(mapping = aes(x = time_to_aGvHD_III_IV,
                       y = aGvHDIIIIV,
                       fill = aGvHDIIIIV)) +
  geom_boxplot(show.legend = FALSE) +
  labs(title = "Time to develop Acute Graft vs. Host disease",
       x = "Time in days",
       y = "Development of Acute Graft vs. Host disease")

# %% [markdown]
# This is in statistics INSERT HERE!
